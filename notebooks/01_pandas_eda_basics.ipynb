# %%
import pandas as pd

# %%
data = {
    "name": ["Alice", "Bob", "Charlie", "Diana", "Eva"],
    "age": [25, 40, 35, 29, 50],
    "experience": [2, 15, 10, 5, 20],
    "salary": [50000, 90000, 80000, 60000, 120000],
    "department": ["IT", "HR", "IT", "Marketing", "IT"],
    "last": [50000, 90000, 80000, 60000, 120000],
}

df = pd.DataFrame(data)
df
